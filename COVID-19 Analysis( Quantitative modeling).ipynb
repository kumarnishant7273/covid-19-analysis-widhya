# %% [markdown]
# # COVID-19 Analysis (Quantitative Modelling)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#reading the data by read_csv function
df=pd.read_csv("https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv")
df
# Out:
#      Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0      1  30/01/20               Kerala                        1
# 1      2  31/01/20               Kerala                        1
# 2      3  01/02/20               Kerala                        2
# 3      4  02/02/20               Kerala                        3
# 4      5  03/02/20               Kerala                        3
# ..   ...       ...                  ...                      ...
# 265  266  21/03/20    Jammu and Kashmir                        4
# 266  267  21/03/20               Ladakh                       13
# 267  268  21/03/20        Uttar Pradesh                       23
# 268  269  21/03/20          Uttarakhand                        3
# 269  270  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# 3                           0      0       0
# 4                           0      0       0
# ..                        ...    ...     ...
# 265                         0      0       0
# 266                         0      0       0
# 267                         1      9       0
# 268                         0      0       0
# 269                         0      0       0
#
# [270 rows x 7 columns]

# %%
#sorting the data by DATE 
sort_df=df.groupby('Date', sort = False).sum()
sort_df.head()
# Out:
#           Sno  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# Date
# 30/01/20    1                        1                         0      0
# 31/01/20    2                        1                         0      0
# 01/02/20    3                        2                         0      0
# 02/02/20    4                        3                         0      0
# 03/02/20    5                        3                         0      0
#
#           Deaths
# Date
# 30/01/20       0
# 31/01/20       0
# 01/02/20       0
# 02/02/20       0
# 03/02/20       0

# %%
#droping the coloumn Sno
sort_df = sort_df.drop('Sno', axis =1)
sort_df.head()
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0

# %%
#creating new coloumn 'Total cases' and using sum function 
sort_df['Total_cases'] = sort_df.sum(axis =1)
sort_df.head()
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
#
#           Total_cases
# Date
# 30/01/20            4
# 31/01/20            4
# 01/02/20            8
# 02/02/20           12
# 03/02/20           12

# %%
#visualizing the data using matplotlib
plt.plot(sort_df['Total_cases'])
plt.xlabel('Dates')
plt.ylabel('Total cases')
plt.show()

# %%
plt.figure(figsize = (12,10))
plt.plot(sort_df['Total_cases'])
plt.xlabel('Dates')
plt.ylabel('Total cases')
plt.xticks(rotation = 90, fontsize = 14)
plt.show()

# %% [markdown]
# we can see in the obtained graph that the treand in the spread follows an exponential curve.

# %%
sort_df.tail(18)
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 04/03/20                       12                        16      3       0
# 05/03/20                       14                        16      3       0
# 06/03/20                       15                        16      3       0
# 07/03/20                       18                        16      3       0
# 08/03/20                       23                        16      3       0
# 09/03/20                       30                        16      3       0
# 10/03/20                       42                        16      3       0
# 11/03/20                       44                        16      3       0
# 12/03/20                       57                        17      3       0
# 13/03/20                       64                        17      3       1
# 14/03/20                       67                        17     10       2
# 15/03/20                       93                        17     13       2
# 16/03/20                       97                        17     13       2
# 17/03/20                      113                        24     14       3
# 18/03/20                      126                        25     14       3
# 19/03/20                      148                        25     20       4
# 20/03/20                      191                        32     23       4
# 21/03/20                      244                        39     23       4
#
#           Total_cases
# Date
# 04/03/20          124
# 05/03/20          132
# 06/03/20          136
# 07/03/20          148
# 08/03/20          168
# 09/03/20          196
# 10/03/20          244
# 11/03/20          252
# 12/03/20          308
# 13/03/20          340
# 14/03/20          384
# 15/03/20          500
# 16/03/20          516
# 17/03/20          616
# 18/03/20          672
# 19/03/20          788
# 20/03/20         1000
# 21/03/20         1240

# %%
#modelling the solution
rate_list = []
for i in range(0, sort_df.shape[0]-1):
    
    rate = (sort_df.iloc[i+1]['Total_cases'] - sort_df.iloc[i]['Total_cases'])/sort_df.iloc[i]['Total_cases']
    rate_list.append(rate)

# %%
#avg of the rate_list
avg_rate=np.average(rate_list)
avg_rate
# Out:
# 0.15548289717820452

# %%
# P_t = p_o*(e^(r*t))
# t is the time period in days, r is the rate of increase
#P_t and P_o are the predicted forecast and the inital values respectively.
P_o =31
t=26
p_t = round(P_o* (math.exp(avg_rate *t)),2)
p_t
# Out:
# 1766.12

# %% [markdown]
# ******************************END*******************************
